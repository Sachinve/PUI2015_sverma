# %%
import geopandas as gp
import pandas as pd
import os
import json
import matplotlib.pyplot as plt 
import pylab as pl
s = json.load( open(os.getenv('PUI2015')+'/fbb_matplotlibrc.json') )
pl.rcParams.update(s)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/sachinv/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:855: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
nrg = gp.GeoDataFrame.from_csv("Energy_and_Water_Data_Disclosure_for_Local_Law_84__2013_.csv")
print nrg.columns
# Out:
# Index([u'NYC Borough, Block, and Lot (BBL)', u'Co-reported BBL Status',
#        u'BBLs Co-reported',
#        u'Reported NYC Building Identificaiton Numbers (BINs)',
#        u'Street Number', u'Street Name', u'Borough', u'Zip Code',
#        u'DOF Benchmarking Submission Status', u'Site EUI(kBtu/ft2)',
#        u'Weather Normalized Site EUI(kBtu/ft2)', u'Source EUI(kBtu/ft2)',
#        u'Weather Normalized Source EUI(kBtu/ft2)',
#        u'Municipally Supplied Potable Water - Indoor Intensity (gal/ft²)',
#        u'Automatic Water Benchmarking Eligible', u'Reported Water Method',
#        u'ENERGY STAR Score', u'Total GHG Emissions(MtCO2e)',
#        u'Direct GHG Emissions(MtCO2e)', u'Indirect GHG Emissions(MtCO2e)',
#        u'Reported Property Floor Area (Building(s)) (ft²)',
#        u'DOF Property Floor Area (Buildngs and Parking)(ft2)',
#        u'Primary Property Type - Self Selected', u'DOF Number of Buildings'],
#       dtype='object')

# %%
#print(nrg.head())
#print (nrg['Site EUI(kBtu/ft2)'])
#print nrg['Site EUI(kBtu/ft2)'].astype(float)

# %%
bsize = gp.GeoDataFrame.from_file("Manhattan/MNMapPLUTO.shp")
print bsize.columns
# Out:
# Index([    u'APPBBL',    u'APPDate',    u'Address', u'AllZoning1',
#        u'AllZoning2', u'AreaSource', u'AssessLand',  u'AssessTot',
#               u'BBL',   u'BldgArea',  u'BldgClass',  u'BldgDepth',
#         u'BldgFront',      u'Block',   u'BoroCode',    u'Borough',
#          u'BsmtCode',  u'BuiltCode',   u'BuiltFAR',     u'CB2010',
#                u'CD',     u'CT2010',    u'ComArea',    u'CommFAR',
#           u'CondoNo',    u'Council',  u'EDesigNum',  u'Easements',
#        u'ExemptLand',  u'ExemptTot',        u'Ext',   u'FacilFAR',
#        u'FactryArea',   u'FireComp', u'GarageArea', u'HealthArea',
#          u'HistDist', u'IrrLotCode',    u'LandUse',   u'Landmark',
#               u'Lot',    u'LotArea',   u'LotDepth',   u'LotFront',
#           u'LotType',  u'LtdHeight', u'MAPPLUTO_F',   u'NumBldgs',
#         u'NumFloors', u'OfficeArea',  u'OtherArea',   u'Overlay1',
#          u'Overlay2',  u'OwnerName',  u'OwnerType', u'PLUTOMapID',
#        u'PolicePrct',   u'ProxCode',    u'ResArea',   u'ResidFAR',
#        u'RetailArea', u'SHAPE_Area', u'SHAPE_Leng',    u'SPDist1',
#           u'SPDist2',    u'Sanborn', u'SchoolDist',  u'SplitZone',
#         u'StrgeArea',     u'TaxMap',  u'Tract2010',   u'UnitsRes',
#        u'UnitsTotal',    u'Version',     u'XCoord',     u'YCoord',
#        u'YearAlter1', u'YearAlter2',  u'YearBuilt',     u'ZMCode',
#           u'ZipCode',  u'ZoneDist1',  u'ZoneDist2',  u'ZoneDist3',
#         u'ZoneDist4',    u'ZoneMap',   u'geometry'],
#       dtype='object')

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix (nrg, s=300, figsize=(16, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x134cb8a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121388e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13051fed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1331b7d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x110967c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e0c4710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11587a950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1182fe690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a6e8dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cdd1c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f4b5950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122d7e910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127846650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128b04590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c41d2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12de8f250>]], dtype=object)

# %%
def canconvert(mydata):
    try :
        float(mydata)
        return True
    except ValueError:
        return False

# %%
vfunc = np.vectorize(canconvert)

# %%
#a=NaN
#vfunc([2,a,3])

# %%
indx=vfunc(nrg['Site EUI(kBtu/ft2)'])
indx2=vfunc(nrg['Reported Property Floor Area (Building(s)) (ft²)'])
indx3=vfunc(bsize['UnitsRes'])

print(indx)
print(indx2)
# Out:
# [ True  True  True ...,  True  True  True]
# [ True  True  True ...,  True  True  True]

# %%
nrg['Site EUI(kBtu/ft2)'][~indx]=float('NaN')
nrg['Reported Property Floor Area (Building(s)) (ft²)'][~indx2]=float('NaN')
bsize['UnitsRes'][~indx3]=float('NaN')
# Out:
# /Users/sachinv/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/sachinv/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /Users/sachinv/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
#print (nrg['Site EUI(kBtu/ft2)'].astype(float))
#print (bsize.BBL.astype(float))
#print('------------------')
#print (nrg['NYC Borough, Block, and Lot (BBL)'].astype(float))

# %%
nrg['BBL']=nrg['NYC Borough, Block, and Lot (BBL)']
#print(nrg['BBL'])

# %%
#bblnrgdata=pd.merge(bsize,nrg,on='BBL',how='inner')
bblnrgdata=pd.merge(bsize,nrg,on='BBL')
#print(bblnrgdata.head())
#print(bblnrgdata.columns)
# Out:
# /Users/sachinv/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1695: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   indexer = self._engine.get_indexer(target.values)
# /Users/sachinv/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1049: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   return key in self._engine

# %%
bblnrgdata['TotalEnergy'] = bblnrgdata['Site EUI(kBtu/ft2)'].astype(float) * bblnrgdata['Reported Property Floor Area (Building(s)) (ft²)'].astype(float)
# Out:
# /Users/sachinv/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1572: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   return self._engine.get_loc(_values_from_object(key))

# %%
import matplotlib.pyplot as plt

ax1 = plt.subplot(111)
ax1.scatter(bblnrgdata['TotalEnergy'], bblnrgdata['UnitsTotal'])
ax1.set_xlim([1000, 1e10])
ax1.set_ylim([1, 1000])
ax1.set_xlabel('Total Energy')
ax1.set_ylabel('UnitsTotal')
plt.show()

# %%
ax2 = plt.subplot(111)
ax2.scatter(bblnrgdata['TotalEnergy'], bblnrgdata['UnitsTotal'])
ax2.set_xlim([1000, 1e10])
ax2.set_ylim([1, 1000])

ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('Total Energy')
ax2.set_ylabel('UnitsTotal')


plt.show()
#pl.scatter(bblnrgdata['TotalEnergy'], bblnrgdata['UnitsTotal'],loglog=True)

# %%
sane_data = bblnrgdata[(bblnrgdata['UnitsTotal'] > 0) & (bblnrgdata['UnitsTotal']< 1000) & (bblnrgdata['TotalEnergy'] > 0) & (bblnrgdata['TotalEnergy']<1e10)]

print (sane_data)
# Out:
#           APPBBL     APPDate                   Address AllZoning1 AllZoning2  \
# 0              0        None              322 8 AVENUE      C6-2A       None
# 1              0        None          42 TRINITY PLACE    C5-5/LM       None
# 3              0        None              114 5 AVENUE      C6-4M      C6-4A
# 6529  1007180101  11/04/2009              177 9 AVENUE   C2-5/R7B       None
# 6530  1000160235  09/26/2011      200 NORTH END AVENUE    BPC/BPC       None
# 6531  1010470018  02/19/2015        322 WEST 57 STREET    C6-4/CL       None
# 6532  1010470018  02/19/2015        322 WEST 57 STREET    C6-4/CL       None
# 6533           0        None             1405 5 AVENUE  C1-4/R7-2       None
# 6535  1010510001  05/24/2011        450 WEST 42 STREET    C6-4/CL       None
# 6536  1007760033  10/18/2010        210 WEST 27 STREET       C6-2       None
# 6538  1018520005  03/21/2011       790 COLUMBUS AVENUE       R7-2       None
# 6539  1010370038  07/25/2013        306 WEST 47 STREET    C6-4/CL       None
# 6543  1020950038  11/27/2007       608 WEST 149 STREET         R8       None
# 6544  1014730043  08/11/2005        408 EAST 79 STREET  C1-5/R10A       None
#
#      AreaSource  AssessLand  AssessTot         BBL  BldgArea      ...       \
# 0             7     2259000   12143700  1007760001    173491      ...
# 1             7     2272500    4211233  1000190013     62089      ...
# 3             7     6435000   59960259  1008180051    300168      ...
# 4             7     5985000   15545250  1008480043    111569      ...
# 5             7      194400    1721700  1019900010     58750      ...
# 6             7     4140000   14761800  1015890041    210000      ...
# 7             7      427950    2600550  1019620056    110280      ...
# 8             7     1170000    9702000  1005210009     69300      ...
# 9             7      900000    4435650  1008230010     70000      ...
# 10            7    28800022  136216809  1011147503    695701      ...
# 12            7      614249    5896801  1006097502     47076      ...
# 14            7     7294050   19004400  1002600001    513000      ...
# 16            7     4050000   18114300  1008340022    206388      ...
# 17            7      153900    1970550  1021770018     56850      ...
# 18            7     2532600   10153800  1008477501    103167      ...
# 19            7      359550    2062800  1021700105     90211      ...
# 20            7      315000    2898000  1021790207     68432      ...
# 23            7     1710000    5467050  1010250044         0      ...
# 25            7    19128600  164540027  1010827501   1082317      ...
# 26            7      145350    1470600  1021100037     63720      ...
# 28            7      418950    4117500  1019700016     53835      ...
# 29            7      734853   15135300  1010387501     97076      ...
# 30            7      734853   15135300  1010387501     97076      ...
# 32            7     2034000    8705700  1013100027    137136      ...
# 33            7      175050    2911500  1019630025     50220      ...
# 34            7     1305000    8053200  1018870065    141460      ...
# 35            7     1346706    3238817  1014920001     35131      ...
# 36            7      282150    1614600  1021640038     52598      ...
# 38            7     1372500    6192900  1008270068     65150      ...
# 39            7      260100    1592550  1021800023     54888      ...
# ...         ...         ...        ...         ...       ...      ...
# 6507          7     1598400   33741450  1019107501    284579      ...
# 6508          7     6079496   25631547  1008497504    185471      ...
# 6509          7     3532516   35589322  1014297502    215331      ...
# 6510          7     1793250   48821850  1011710133    367786      ...
# 6512          7     1309050   13382100  1010810001    154944      ...
# 6513          7      900000    4742992  1018877501     71303      ...
# 6515          7     1952100   32314050  1000167519    233010      ...
# 6516          7      792000    4128750  1003460001    137909      ...
# 6517          7    69750003  289783352  1000627501   1690747      ...
# 6518          7     1060206    8977052  1001907503     82955      ...
# 6519          7     6094350   83816103  1007217501    685775      ...
# 6520          7     4712850   18921600  1013720002    231680      ...
# 6521          7     5256000   27100351  1005067501    311477      ...
# 6522          7      411750    5901793  1020347501    145708      ...
# 6523          7     2747251    5971501  1004517502     76583      ...
# 6524          7      823953    4094250  1017457502     68694      ...
# 6525          7     4253850   25404750  1015540023    244249      ...
# 6527          7     1183500   12182850  1016940007    412985      ...
# 6528          7     2620800   38724301  1010817502    326404      ...
# 6529          7     5234732   19793250  1007187501    146020      ...
# 6530          7     3624751   57521250  1000167520    377325      ...
# 6531          7    39630127  115488149  1010477503    789167      ...
# 6532          7    39630127  115488149  1010477503    789167      ...
# 6533          7      452700    4431150  1016217501     71951      ...
# 6535          7    14759985  178440173  1010517502   1003752      ...
# 6536          7     1555650   12697200  1007760033         0      ...
# 6538          7      653400   11303100  1018520020    257760      ...
# 6539          7      116100     759150  1010370038      7185      ...
# 6543          7      170108    4212006  1020957501     65865      ...
# 6544          7     1349999   11520003  1014737504     87450      ...
#
#      Reported Water Method  ENERGY STAR Score  Total GHG Emissions(MtCO2e)  \
# 0                     None                 87                       1027.5
# 1                      ABS      Not Available                        246.6
# 3                      ABS                 70                         1604
# 4                      ABS                 95                        518.5
# 5                     None                100                         21.8
# 6                   Manual      Not Available                         1331
# 7                      ABS      Not Available                        455.5
# 8                   Manual      Not Available                         10.8
# 9                     None      Not Available                        294.8
# 10                    None      Not Available                       5641.9
# 12                     ABS      Not Available                          287
# 14                    None      Not Available                       7416.5
# 16                  Manual                 75           1095.5999999999999
# 17                     ABS      Not Available                        190.9
# 18                    None                 39                          493
# 19                     ABS      Not Available                        769.7
# 20                  Manual      Not Available                        508.9
# 23                    None      Not Available                        806.9
# 25                    None      Not Available                       6155.4
# 26                    None      Not Available                        481.1
# 28                    None      Not Available                        981.2
# 29                    None      Not Available                        706.7
# 30                    None      Not Available                        706.7
# 32                     ABS                 90                       1115.3
# 33                    None      Not Available                        439.6
# 34                    None      Not Available                        630.9
# 35                    None      Not Available                         54.2
# 36                    None      Not Available                        222.8
# 38                  Manual      Not Available                          317
# 39                     ABS      Not Available                        376.8
# ...                    ...                ...                          ...
# 6507                  None      Not Available                       1512.4
# 6508                Manual      Not Available                     444357.1
# 6509                  None      Not Available                         1670
# 6510                   ABS      Not Available                         2263
# 6512                  None      Not Available                         97.1
# 6513                  None      Not Available           549.29999999999995
# 6515                  None      Not Available                       1607.6
# 6516                  None      Not Available                        850.5
# 6517                Manual                 82           24293.200000000001
# 6518                  None      Not Available                        370.1
# 6519                  None      Not Available           4517.1000000000004
# 6520                  None      Not Available                       1300.8
# 6521                   ABS                 75           2364.3000000000002
# 6522                   ABS      Not Available                        532.1
# 6523                  None      Not Available                        295.2
# 6524                  None      Not Available                          208
# 6525                  None      Not Available           1175.9000000000001
# 6527                  None      Not Available                       1427.6
# 6528                  None      Not Available           2296.6999999999998
# 6529                  None      Not Available                        707.7
# 6530                   ABS      Not Available           2506.8000000000002
# 6531                  None      Not Available                       5230.8
# 6532                Manual      Not Available                         5099
# 6533                  None      Not Available           523.70000000000005
# 6535                  None      Not Available                       5505.1
# 6536                Manual                 52                       1009.2
# 6538                  None      Not Available                       1863.4
# 6539                  None      Not Available                         13.5
# 6543                  None      Not Available                        415.6
# 6544                   ABS      Not Available           567.29999999999995
# 6533                   Multifamily Housing                        3
# 6535                   Multifamily Housing                      NaN
# 6536              Residence Hall/Dormitory                        1
# 6538                   Multifamily Housing                        1
# 6539                   Multifamily Housing                      NaN
# 6543                   Multifamily Housing                      NaN
# 6544                   Multifamily Housing                        1
#
#        TotalEnergy
# 0     1.306598e+07
# 1     3.483193e+06
# 3     2.009132e+07
# 4     6.367118e+06
# 5     4.026892e+05
# 6     1.749440e+07
# 7     6.158218e+06
# 8     1.732500e+05
# 9     4.476150e+06
# 10    6.690180e+07
# 12    3.864679e+06
# 14    1.200654e+08
# 16    1.395270e+07
# 17    2.592144e+06
# 18    6.063920e+06
# 19    1.009851e+07
# 20    6.726866e+06
# 23    1.316590e+07
# 25    9.199628e+07
# 26    6.463120e+06
# 28    1.711953e+07
# 29    9.990000e+06
# 30    9.990000e+06
# 32    1.276800e+07
# 33    6.036444e+06
# 34    8.217649e+06
# 35    6.662280e+05
# 36    2.927815e+06
# 38    5.127305e+06
# 39    5.015535e+06
# ...            ...
# 6507  1.915519e+07
# 6508  5.019269e+09
# 6509  2.072551e+07
# 6510  3.589795e+07
# 6512  1.225527e+06
# 6513  7.474095e+06
# 6515  2.510685e+07
# 6516  1.129752e+07
# 6517  2.906933e+08
# 6518  5.641197e+06
# 6519  5.937562e+07
# 6520  1.508177e+07
# 6521  2.984940e+07
# 6522  9.089136e+06
# 6523  4.736770e+06
# 6524  3.147102e+06
# 6525  1.809885e+07
# 6527  1.755190e+07
# 6528  3.758666e+07
# 6529  1.003090e+07
# 6530  3.636416e+07
# 6531  6.810865e+07
# 6532  6.645316e+07
# 6533  8.864807e+06
# 6535  7.996946e+07
# 6536  1.174767e+07
# 6538  2.464186e+07
# 6539  1.839528e+05
# 6543  7.205631e+06
# 6544  8.497289e+06
#
# [4956 rows x 112 columns]

# %%
import statsmodels.api as sm
lm = sm.OLS(sane_data['UnitsTotal'], sane_data['TotalEnergy'],missing='drop').fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             UnitsTotal   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     28.44
# Date:                Wed, 14 Oct 2015   Prob (F-statistic):           1.01e-07
# Time:                        18:35:59   Log-Likelihood:                -32147.
# No. Observations:                4956   AIC:                         6.430e+04
# Df Residuals:                    4955   BIC:                         6.430e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# TotalEnergy  2.644e-08   4.96e-09      5.333      0.000      1.67e-08  3.62e-08
# ==============================================================================
# Omnibus:                     2999.164   Durbin-Watson:                   1.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30214.612
# Skew:                           2.794   Prob(JB):                         0.00
# Kurtosis:                      13.728   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
Y=sane_data['TotalEnergy']
X=sane_data['UnitsTotal']

X1=sm.add_constant(np.log10(X))
Y1=np.log10(Y)

lm1=sm.OLS(Y1,X1).fit()


X2=np.arange(0,4,1)
Y2 = (lm1.params)[1]*X2 + (lm1.params)[0]


ax3 = plt.subplot(111)
ax3.plot(X1,Y1,'o')
ax3.plot(X2,Y2,'blue')

plt.show()

# %%
X3=np.log10(X)
Y3=np.log10(Y)

pm=np.polyfit(X3,Y3,2)

ax4 = plt.subplot(111)

X4 = np.arange(0,5,.2)
Y4=pm[0]*X4**2 + pm[1]*X4 + pm[2]


ax4.plot(X3,Y3,'oy')
ax4.plot(X4,Y4,'r')
plt.show()
